# %%
import mechanicalsoup
import pandas as pd
import concurrent.futures
dic = {'area of study':[],
       'course_name':[],
       'university_name':[],
       'course_fee':[],
       'course_link':[],
      }
df = pd.DataFrame(dic)

browser = mechanicalsoup.StatefulBrowser()
browser.open("https://www.idp.com/global/search/all-accounting/")
count=0
while True:
    count+=1
    print(count)
    soup = browser.page
    cards = soup.find('ul', class_='product__listing product__list').find_all('li')
    for card in cards:
        dic = {}
        prd_inner_cont = card.find('div', class_='prd_inner_cont')
        right_content = card.find('div', class_='right-content')
        dic['area of study'] = 'accounting'
        try:
            dic['course_name'] = prd_inner_cont.find('h2').find('a').text.strip('\n')
        except:
            pass
        try:
            dic['university_name'] = prd_inner_cont.find('h3').find('a').find('span', class_='uniname').text
        except:
            pass
        try:
            score = right_content.find("div", class_="score")
            try:
                dic['course_fee'] = score.find_all("p")[1].text.replace('\xa0\n', ' ').split('?')[0].strip('\n')
            except:
                pass
            try:
                dic['course_link'] = 'https://www.idp.com' + prd_inner_cont.find('h2').find('a')['href']
            except:
                pass
        except:
            pass
        df = df.append(dic, ignore_index=True)
    next_page = soup.find('a', {'rel':'next'})
    if next_page:
        next_page_url = 'https://www.idp.com' + next_page['href']
        browser.open(next_page_url)
        continue
    break
df.to_csv("link_info.csv")
# Out:
# 1
# 2
# 3
# 4

# %%
df
# Out:
#     area of study                                        course_name  \
# 0      accounting           MSc International Accounting and Finance
# 1      accounting  MSc International Accounting and Finance (Path...
# 2      accounting  MSc International Accounting and Finance (Path...
# 3      accounting               MSc Accounting and Finance Pathway 2
# 4      accounting               MSc Accounting and Finance Pathway 3
# ..            ...                                                ...
# 145    accounting                     Graduate Diploma in Accounting
# 146    accounting                    Master of Commerce - Accounting
# 147    accounting                  Master of Professional Accounting
# 148    accounting  Bachelor of Applied Management - Accounting (w...
# 149    accounting  Master of Commerce (2 years)- with a Specialis...
#
#                      university_name  course_fee  \
# 0           University of Birmingham  GBP 23,580
# 1           University of Birmingham  GBP 23,580
# 2           University of Birmingham  GBP 31,440
# 3           University of Birmingham  GBP 29,733
# 4           University of Birmingham  GBP 42,968
# ..                               ...         ...
# 145        The University of Waikato  NZD 30,260
# 146       The University of Auckland  NZD 38,258
# 147                  RMIT University  AUD 60,480
# 148  Waikato Institute of Technology  NZD 60,630
# 149             Macquarie University  AUD 78,400
#
#                                            course_link
# 0    https://www.idp.com/global/Categories/All-Acco...
# 1    https://www.idp.com/global/Categories/Universi...
# 2    https://www.idp.com/global/Categories/All-Acco...
# 3    https://www.idp.com/global/Categories/Universi...
# 4    https://www.idp.com/global/Categories/Universi...
# ..                                                 ...
# 145  https://www.idp.com/global/Categories/All-Acco...
# 146  https://www.idp.com/global/Categories/The-Univ...
# 147  https://www.idp.com/global/Categories/All-Acco...
# 148  https://www.idp.com/global/Categories/All-Acco...
# 149  https://www.idp.com/global/Categories/All-Acco...
#
# [150 rows x 5 columns]

# %%
for card in cards:
    try:
        course_name = card.xpath(".//div[@class='prd_inner_cont']/h2/a/text()")
    except:
        course_name = None
    university_name = card.xpath(".//div[@class='prd_inner_cont']/h3/a/span[@class='uniname']/text()")

    right_content = card.xpath(".//div[@class='right-content']")
    score = right_content.xpath(".//div[@class='score']")
    try:
        course_fee = score.xpath(".//p/text()")
    except:
        course_fee = None
    course_link = card.xpath(".//div/div/a/@href")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-336c65982200> in <module>
#       7
#       8     right_content = card.xpath(".//div[@class='right-content']")
# ----> 9     score = right_content.xpath(".//div[@class='score']")
#      10     try:
#      11         course_fee = score.xpath(".//p/text()")
#
# AttributeError: 'list' object has no attribute 'xpath'
